# %%
import pandas as pd
import numpy as np
import streamlit as st
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
df=pd.read_csv("C:/Users/CS-04/Documents/placement1.csv")
print(df)
print(df.isnull().sum())
# Out:
#      cgpa  package
# 0    6.89     3.26
# 1    5.12     1.98
# 2    7.82     3.25
# 3    7.42     3.67
# 4    6.94     3.57
# ..    ...      ...
# 195  6.93     2.46
# 196  5.89     2.57
# 197  7.21     3.24
# 198  7.63     3.96
# 199  6.22     2.33
#
# [200 rows x 2 columns]
# cgpa       0
# package    0
# dtype: int64

# %%
x=df.iloc[:,[-2]].values
y=df.iloc[:,[-1]].values
print(x.shape,y.shape)
# Out:
# (200, 1) (200, 1)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)
print(x_train,x_test,y_train,y_test)
# Out:
# [[5.66]
#  [6.51]
#  [7.04]
#  [8.28]
#  [5.13]
#  [6.19]
#  [6.93]
#  [6.93]
#  [9.26]
#  [5.91]
#  [6.29]
#  [7.25]
#  [7.78]
#  [6.93]
#  [8.58]
#  [6.96]
#  [5.83]
#  [8.31]
#  [6.66]
#  [8.01]
#  [5.95]
#  [6.14]
#  [7.76]
#  [6.47]
#  [4.85]
#  [6.05]
#  [8.13]
#  [7.37]
#  [6.42]
#  [8.44]
#  [7.11]
#  [7.4 ]
#  [6.1 ]
#  [7.73]
#  [6.78]
#  [6.34]
#  [7.29]
#  [8.93]
#  [6.92]
#  [7.47]
#  [7.28]
#  [6.61]
#  [7.42]
#  [5.9 ]
#  [5.48]
#  [6.89]
#  [8.71]
#  [7.69]
#  [7.82]
#  [6.94]
#  [6.94]
#  [7.87]
#  [6.76]
#  [7.56]
#  [8.22]
#  [7.66]
#  [6.59]
#  [6.1 ]
#  [6.31]
#  [6.35]
#  [6.98]
#  [6.85]
#  [8.09]
#  [7.57]
#  [7.11]
#  [8.35]
#  [7.88]
#  [7.6 ]
#  [6.07]
#  [5.98]
#  [8.63]
#  [7.21]
#  [7.32]
#  [7.05]
#  [6.89]
#  [7.61]
#  [6.87]
#  [7.36]
#  [4.79]
#  [8.65]
#  [4.57]
#  [6.37]
#  [9.16]
#  [7.84]
#  [7.15]
#  [7.48]
#  [6.71]
#  [5.1 ]
#  [8.18]
#  [8.62]
#  [8.44]
#  [5.53]
#  [7.34]
#  [8.2 ]
#  [7.3 ]
#  [6.53]
#  [6.94]
#  [9.31]
#  [6.22]
#  [5.84]
# ...

# %%
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_predict=lr.predict(x_test)
print(y_predict)
# Out:
# [[3.74780671]
#  [4.22590648]
#  [3.37595133]
#  [2.54960605]
#  [4.53283473]
#  [1.67013857]
#  [1.39272266]
#  [2.69716771]
#  [3.53531792]
#  [2.77980224]
#  [3.20477981]
#  [3.17526748]
#  [3.09263295]
#  [3.55892779]
#  [3.95439303]
#  [2.41384933]
#  [3.54712286]
#  [1.96526189]
#  [3.23429214]
#  [3.09263295]
#  [3.11624282]
#  [2.86243677]
#  [3.26380447]
#  [2.52009372]
#  [2.39023946]
#  [2.91555896]
#  [2.97458363]
#  [2.32531233]
#  [2.384337  ]
#  [2.35482466]
#  [2.18955561]
#  [2.9273639 ]
#  [2.57321592]
#  [2.20726301]
#  [4.21410155]
#  [4.18458922]
#  [2.59682578]
#  [2.07740875]
#  [2.53189865]
#  [3.12214528]]

# %%
train_accuracy=lr.score(x_train,y_train)
test_accuracy=lr.score(x_test,y_test)
print(train_accuracy)
print(test_accuracy)
# Out:
# 0.7758239917279399
# 0.7626731255199563

# %%
cgpa = st.text_input("ENTER YOUR CGPA")
if st.button("package predict"):
    try:
        cgpa = float(cgpa)
        if cgpa < 0 or cgpa > 10:
            st.error("please enter a valid CGPA between 0 and 10.")
        else:
            prediction=lr.predict(np.array([[cgpa]]))
            st.success(f"package predict : {prediction[0][0]:.2f} LPA")
    except ValueError:
        st.error("please enter a valid number for CGPA.")
# Out:
# 2026-08-31 14:25:14.334 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-31 14:25:14.335 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-31 14:25:14.336 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-31 14:25:14.337 WARNING streamlit.runtime.state.session_state_proxy: Session state does not function when running a script without `streamlit run`
# 2026-08-31 14:25:14.338 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-31 14:25:14.874
# ...
#   command:
#
# ...
